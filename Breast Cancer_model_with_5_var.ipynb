# %% [markdown]
# En el apartado "Loading Data" de esta URL:
#
# https://www.datacamp.com/community/tutorials/svm-classification-scikit-learn-python
#
# Se explica cómo se cargan una serie de datos:
#
# 1. Utiliza esa misma forma para cargar los datos.
# 2. Limpia los datos si es necesario
# 3. Dibuja con plotly los que creas necesarios gráficos para entender los datos.
# 4. Utiliza los métodos de clasificación vistos hasta ahora para clasificar el target de los datos, ¿cuál da mejores resultados?
# 5. Intenta superarte en el score cambiando las features de los algoritmos.

# %%
import pandas as pd
import numpy as np

from sklearn import datasets
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import precision_score 
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(8,8));
pd.options.plotting.backend = "plotly"
sns.set(rc={'figure.figsize':(8,8)})
from imblearn.over_sampling import SMOTE

from lightgbm import LGBMClassifier 
from sklearn.ensemble import RandomForestClassifier

# %%
cancer = datasets.load_breast_cancer()

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(cancer['DESCR'])
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 0 is Mean Radius, field
#         10 is Radius SE, field 20 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
cancer.feature_names
columns = [col.replace(' ','_') for col in cancer.feature_names]
columns
# Out:
# ['mean_radius',
#  'mean_texture',
#  'mean_perimeter',
#  'mean_area',
#  'mean_smoothness',
#  'mean_compactness',
#  'mean_concavity',
#  'mean_concave_points',
#  'mean_symmetry',
#  'mean_fractal_dimension',
#  'radius_error',
#  'texture_error',
#  'perimeter_error',
#  'area_error',
#  'smoothness_error',
#  'compactness_error',
#  'concavity_error',
#  'concave_points_error',
#  'symmetry_error',
#  'fractal_dimension_error',
#  'worst_radius',
#  'worst_texture',
#  'worst_perimeter',
#  'worst_area',
#  'worst_smoothness',
#  'worst_compactness',
#  'worst_concavity',
#  'worst_concave_points',
#  'worst_symmetry',
#  'worst_fractal_dimension']

# %%
df = pd.DataFrame(cancer.data, columns=columns)
df
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean_compactness  mean_concavity  mean_concave_points  mean_symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean_fractal_dimension  ...  worst_radius  worst_texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst_perimeter  worst_area  worst_smoothness  worst_compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst_concavity  worst_concave_points  worst_symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst_fractal_dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
# print the cancer labels (0:malignant, 1:benign)
y = cancer.target

# %%
df['target'] = y

# %%
X = df.drop([
 'mean_perimeter',
 'mean_area',
 'mean_smoothness',
 'mean_compactness',
 'mean_concavity',
 'mean_concave_points',
 'mean_fractal_dimension',
 #'radius_error',
 'texture_error',
 'perimeter_error',
 'area_error',
 'smoothness_error',
 'compactness_error',
 'concavity_error',
 'concave_points_error',
 'symmetry_error',
 'fractal_dimension_error',
 #'worst_radius',
 'worst_texture',
 'worst_perimeter',
 'worst_area',
 'worst_smoothness',
 'worst_compactness',
 'worst_concavity',
 'worst_concave_points',
 'worst_symmetry',
 'worst_fractal_dimension',
 'target'], axis=1)
y = df.target
X
# Out:
#      mean_radius  mean_texture  mean_symmetry  radius_error  worst_radius
# 0          17.99         10.38         0.2419        1.0950        25.380
# 1          20.57         17.77         0.1812        0.5435        24.990
# 2          19.69         21.25         0.2069        0.7456        23.570
# 3          11.42         20.38         0.2597        0.4956        14.910
# 4          20.29         14.34         0.1809        0.7572        22.540
# ..           ...           ...            ...           ...           ...
# 564        21.56         22.39         0.1726        1.1760        25.450
# 565        20.13         28.25         0.1752        0.7655        23.690
# 566        16.60         28.08         0.1590        0.4564        18.980
# 567        20.60         29.33         0.2397        0.7260        25.740
# 568         7.76         24.54         0.1587        0.3857         9.456
#
# [569 rows x 5 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mean_radius    569 non-null    float64
#  1   mean_texture   569 non-null    float64
#  2   mean_symmetry  569 non-null    float64
#  3   radius_error   569 non-null    float64
#  4   worst_radius   569 non-null    float64
# dtypes: float64(5)
# memory usage: 22.4 KB

# %%
sns.scatterplot(x=X.mean_radius, y=X.mean_symmetry, hue=y);

# %%
smote = SMOTE()

# %%
pd.DataFrame(y).value_counts()
# Out:
# target
# 1         357
# 0         212
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25 , random_state=42, stratify=y)

# %%
X_train.shape, X_test.shape
# Out:
# ((426, 5), (143, 5))

# %% [markdown]
# ## Modelos

# %%
rf = RandomForestClassifier(n_estimators=300, verbose=1)
lgbm = LGBMClassifier(verbose=0)

models = [rf, lgbm]

# %%
for model in models:
    
    X_train,y_train = smote.fit_resample(X_train, y_train)
    
    name = str(model)[:14]
    print(f'Entrenando {name} ........\n')
    model.fit(X_train, y_train)

    print('Modelo entrenado :)\n')
    print('Vamos al lio........\n')
    model_pred = model.predict(X_train)
    acc_model = accuracy_score(y_train, model_pred)
    ps_model = precision_score(y_train, model_pred, average='macro')
    f1_model = f1_score(y_train, model_pred, average='macro')
    rs_model = recall_score(y_train, model_pred, average='macro')
    cm_model = confusion_matrix(y_train, model_pred)
    pred = model.predict(X_test)
    acc_model_all = accuracy_score(y_test, pred)
    ps_model_all = precision_score(y_test, pred, average='macro')
    f1_model_all = f1_score(y_test, pred, average='macro')
    rs_model_all = recall_score(y_test, pred, average='macro')
    cm_model_all = confusion_matrix(y_test, pred)
    
    print(f'-----------Matriz Confusión {name} ---------------------------\n')
    sns.heatmap(cm_model, annot=True)
    sns.set(rc={'figure.figsize':(8,8)})
    plt.title('Matriz confusion')
    plt.ylabel('Verdad')
    plt.xlabel('Prediccion')
    plt.show();
    
    print(f'-----------Resultados para el modelo {name}-----------|n')
    print(f'Accuracy: {acc_model}')
    print(f'Precision score: {ps_model}')
    print(f'f_1 score: {f1_model}')
    print(f'Recall score: {rs_model}')
    print('--------------------------------------------------------\n')
    
    print(f'-----------Matriz Confusión X_test {name} ------------------------|n')
    
    sns.heatmap(cm_model_all, annot=True)
    sns.set(rc={'figure.figsize':(8,8)})
    plt.title('Matriz confusion')
    plt.ylabel('Verdad')
    plt.xlabel('Prediccion')
    plt.show();
    
    
    
    print(f'-----------Resultados para X_test {name}-----------|n')
    print(f'Accuracy: {acc_model_all}')
    print(f'Precision score: {ps_model_all}')
    print(f'f_1 score: {f1_model_all}')
    print(f'Recall score: {rs_model_all}')
    print('--------------------------------------------------------|n')
# Out:
# Entrenando RandomForestCl ........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Modelo entrenado :)
#
# Vamos al lio........
#
# -----------Matriz Confusión RandomForestCl ---------------------------
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# -----------Resultados para el modelo RandomForestCl-----------|n
# Accuracy: 1.0
# Precision score: 1.0
# f_1 score: 1.0
# Recall score: 1.0
# --------------------------------------------------------
#
# -----------Matriz Confusión X_test RandomForestCl ------------------------|n
# -----------Resultados para X_test RandomForestCl-----------|n
# Accuracy: 0.9300699300699301
# Precision score: 0.9227272727272727
# f_1 score: 0.9256138160632543
# Recall score: 0.9289308176100629
# --------------------------------------------------------|n
# Entrenando LGBMClassifier ........
#
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Modelo entrenado :)
#
# Vamos al lio........
#
# -----------Matriz Confusión LGBMClassifier ---------------------------
# -----------Resultados para el modelo LGBMClassifier-----------|n
# Accuracy: 1.0
# Precision score: 1.0
# f_1 score: 1.0
# Recall score: 1.0
# --------------------------------------------------------
#
# -----------Matriz Confusión X_test LGBMClassifier ------------------------|n
# -----------Resultados para X_test LGBMClassifier-----------|n
# Accuracy: 0.916083916083916
# Precision score: 0.9058716707021792
# f_1 score: 0.9119458128078817
# Recall score: 0.9216981132075472
# --------------------------------------------------------|n

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
n_estimators=[int(x) for x in np.linspace(200, 2000, 10)]

criterion = ['gini', 'entropy']

max_depth = [int(x) for x in np.linspace(10, 200, 10)]

min_samples_split = [int(x) for x in np.linspace(2, 10, 1)]

min_samples_leaf = [int(x) for x in np.linspace(1, 10, 1)]

max_features = ['auto', 'sqrt', 'log2']

bootstrap = [True, False]

warm_start = [True, False]

# %%
random_grid={'n_estimators': n_estimators,
             'criterion': criterion,
             'max_depth': max_depth,
             'min_samples_split': min_samples_split,
             'min_samples_leaf': min_samples_leaf,
             'max_features': max_features,
             'bootstrap': bootstrap,
             'warm_start': warm_start,
             }

# %%
rf_random=RandomizedSearchCV(estimator=rf,
                             param_distributions=random_grid,
                             n_iter=100,
                             cv=5,
                             verbose=10,
                             n_jobs=-1,
                             scoring='roc_auc')

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:   34.9s
# [CV] warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False, score=1.000, total=   1.8s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True, score=0.973, total=   1.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=True, score=0.980, total=   0.3s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False, score=0.965, total=   1.6s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True, score=0.974, total=   1.5s
# [CV] warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=gini, bootstrap=True, score=0.994, total=   0.6s
# [CV] warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=False, score=1.000, total=   0.6s
# [CV] warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=52, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=52, criterion=entropy, bootstrap=False, score=0.996, total=   2.9s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=entropy, bootstrap=True, score=1.000, total=   0.3s
# [CV] warm_start=True, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=entropy, bootstrap=True, score=1.000, total=   2.6s
# [CV] warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=True, score=0.995, total=   1.3s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True, score=0.977, total=   0.6s
# [CV] warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True, score=0.980, total=   1.5s
# [CV] warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False, score=0.996, total=   1.2s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=1.000, total=   0.6s
# [CV] warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=True, score=1.000, total=   1.9s
# [CV] warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False, score=0.995, total=   2.5s
# [CV] warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=31, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=31, criterion=gini, bootstrap=True, score=1.000, total=   1.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=True, score=1.000, total=   1.2s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=0.959, total=   0.5s
# [CV] warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=False, score=0.983, total=   0.6s
# [CV] warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False, score=1.000, total=   0.9s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True, score=1.000, total=   1.6s
# [CV] warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=52, criterion=gini, bootstrap=True, score=0.994, total=   2.5s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True, score=0.980, total=   3.1s
# [CV] warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True, score=0.995, total=   1.5s
# [CV] warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=0.967, total=   2.6s
# [CV] warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=52, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=52, criterion=entropy, bootstrap=True, score=1.000, total=   1.3s
# [CV] warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True, score=0.980, total=   2.7s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False, score=0.960, total=   1.1s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True, score=0.980, total=   2.1s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=1.000, total=   2.7s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False, score=1.000, total=   0.9s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True, score=0.999, total=   0.6s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=0.994, total=   0.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=0.963, total=   0.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=1.000, total=   0.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=0.983, total=   0.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=1.000, total=   0.3s
# [CV] warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False, score=1.000, total=   1.2s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False, score=1.000, total=   1.9s
# [CV] warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=entropy, bootstrap=True, score=1.000, total=   2.9s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False, score=0.963, total=   1.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=True, score=0.980, total=   1.3s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=1.000, total=   0.6s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=False, score=0.966, total=   0.3s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=115, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=115, criterion=entropy, bootstrap=False, score=1.000, total=   1.8s
# [CV] warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=True, score=0.999, total=   2.8s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True, score=0.994, total=   3.1s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=True, score=0.972, total=   1.6s
# [CV] warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False, score=0.963, total=   2.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True, score=0.980, total=   1.3s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False, score=1.000, total=   1.6s
# [CV] warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True, score=1.000, total=   2.8s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False, score=0.996, total=   1.2s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True, score=0.999, total=   2.2s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=True, score=0.976, total=   1.6s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=entropy, bootstrap=False, score=0.983, total=   0.8s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False, score=0.959, total=   0.8s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=entropy, bootstrap=False, score=1.000, total=   0.6s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=False, score=1.000, total=   1.9s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=0.995, total=   0.6s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=0.961, total=   0.5s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False, score=1.000, total=   1.9s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=True, score=0.995, total=   0.9s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=52, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=52, criterion=gini, bootstrap=False, score=0.967, total=   1.8s
# [CV] warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=True, score=1.000, total=   2.5s
# [CV] warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=0.995, total=   0.9s
# [CV] warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=136, criterion=entropy, bootstrap=False, score=0.963, total=   0.6s
# [CV] warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False, score=1.000, total=   0.8s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True, score=0.980, total=   1.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True, score=0.999, total=   1.3s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=0.995, total=   1.1s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=94, criterion=gini, bootstrap=True, score=1.000, total=   3.2s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=True, score=0.980, total=   1.6s
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    1.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    2.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=178, criterion=entropy, bootstrap=False, score=1.000, total=   1.8s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=True, score=0.996, total=   1.3s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=True, score=1.000, total=   0.3s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=73, criterion=gini, bootstrap=False, score=0.995, total=   1.6s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True, score=1.000, total=   1.5s
# [CV] warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=gini, bootstrap=True, score=0.970, total=   0.6s
# [CV] warm_start=False, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True, score=0.995, total=   2.1s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=gini, bootstrap=True, score=0.973, total=   2.1s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=False, score=0.983, total=   2.6s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=False, score=0.982, total=   0.8s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=entropy, bootstrap=False, score=1.000, total=   0.6s
# [CV] warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True, score=1.000, total=   1.5s
# [CV] warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=157, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=157, criterion=gini, bootstrap=True, score=1.000, total=   1.8s
# [CV] warm_start=False, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=gini, bootstrap=False, score=1.000, total=   1.9s
# [CV] warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=157, criterion=gini, bootstrap=False, score=1.000, total=   2.5s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False, score=1.000, total=   1.7s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=gini, bootstrap=True, score=1.000, total=   1.0s
# [CV] warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=0.983, total=   0.8s
# [CV] warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=10, criterion=entropy, bootstrap=False, score=0.984, total=   0.3s
# [CV] warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=200, criterion=gini, bootstrap=False, score=0.994, total=   0.8s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True, score=0.974, total=   1.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True, score=1.000, total=   1.2s
# [CV] warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True, score=0.979, total=   2.8s
# [CV] warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=31, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=31, criterion=gini, bootstrap=False, score=0.983, total=   2.7s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False, score=0.965, total=   1.1s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    1.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    1.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# ...
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False, score=0.981, total=   1.1s
# [CV] warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=115, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=115, criterion=gini, bootstrap=True, score=0.977, total=   0.9s
# [CV] warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=73, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=73, criterion=entropy, bootstrap=True, score=1.000, total=   1.6s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=True, score=1.000, total=   1.6s
# [CV] warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=115, criterion=entropy, bootstrap=True, score=0.974, total=   1.3s
# [CV] warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=gini, bootstrap=True, score=1.000, total=   0.6s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=entropy, bootstrap=False, score=0.982, total=   2.8s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=200, criterion=gini, bootstrap=False, score=0.961, total=   1.8s
# [CV] warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=entropy, bootstrap=True
# [CV]  warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=entropy, bootstrap=True, score=0.974, total=   2.9s
# [CV] warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1600, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=178, criterion=gini, bootstrap=True, score=0.980, total=   2.5s
# [CV] warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=gini, bootstrap=True
# [CV]  warm_start=True, n_estimators=1400, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=gini, bootstrap=True, score=1.000, total=   2.2s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=200, criterion=entropy, bootstrap=True, score=0.996, total=   1.6s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=10, criterion=gini, bootstrap=True, score=0.973, total=   1.2s
# [CV] warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True
# [CV]  warm_start=False, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=73, criterion=gini, bootstrap=True, score=1.000, total=   2.8s
# [CV] warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=31, criterion=gini, bootstrap=False
# [CV]  warm_start=True, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=31, criterion=gini, bootstrap=False, score=1.000, total=   2.7s
# [CV] warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=94, criterion=gini, bootstrap=False, score=1.000, total=   1.1s
# [CV] warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=52, criterion=entropy, bootstrap=False, score=1.000, total=   1.8s
# [CV] warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False
# [CV]  warm_start=False, n_estimators=2000, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=94, criterion=entropy, bootstrap=False, score=0.969, total=   2.9s
# [CV] warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=31, criterion=entropy, bootstrap=False
# [CV]  warm_start=True, n_estimators=1800, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=31, criterion=entropy, bootstrap=False, score=0.965, total=   2.7s
# [CV] warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False
# [CV]  warm_start=False, n_estimators=1000, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=178, criterion=gini, bootstrap=False, score=1.000, total=   1.5s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    1.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1600 out of 1600 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1400 out of 1400 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    1.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1800 out of 1800 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   52.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.3s finished
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_estimators=300,
#                                                     verbose=1),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [10, 31, 52, 73, 94, 115,
#                                                       136, 157, 178, 200],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1],
#                                         'min_samples_split': [2],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000],
#                                         'warm_start': [True, False]},
#                    scoring='roc_auc', verbose=10)

# %%
rf_random.best_params_
# Out:
# {'warm_start': False,
#  'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 52,
#  'criterion': 'gini',
#  'bootstrap': True}

# %%
rf_random.best_score_
# Out:
# 0.9904935195074034

# %%
pred = rf_random.predict(X)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    0.0s finished

# %%
acc_rf_random_all = accuracy_score(y, pred)
ps_rf_random_all = precision_score(y, pred, average='macro')
f1_rf_random_all = f1_score(y, pred, average='macro')
rs_rf_random_all = recall_score(y, pred, average='macro')
cm_rf_random_all = confusion_matrix(y, pred)

print(f'-----------Resultados para el modelo completo rf_random-----------')
print(f'Accuracy: {acc_rf_random_all}')
print(f'Precision score: {ps_rf_random_all}')
print(f'f_1 score: {f1_rf_random_all}')
print(f'Recall score: {rs_rf_random_all}')
print('--------------------------------------------------------')
# Out:
# -----------Resultados para el modelo completo rf_random-----------
# Accuracy: 0.9806678383128296
# Precision score: 0.9780712127184339
# f_1 score: 0.9793838542541593
# Recall score: 0.9807621161672215
# --------------------------------------------------------

# %%
sns.heatmap(cm_rf_random_all, annot=True)
# Out:
# <AxesSubplot:>
